# %% [markdown]
# #missing value

# %% [markdown]
# # House price prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #loading the csv file

# %%
df=pd.read_csv('trainHousePrice.csv')
df.shape
# Out:
# (1460, 81)

# %%
df.head(6)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# #Above is limited option showing ,to know much about dataset use set_option

# %%
pd.set_option('display.max_rows',None)

# %%
pd.set_option('display.max_columns',None)

# %%
df.head(6)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...

# %% [markdown]
# #Dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
df.isnull().sum()  #it give true for NaN value ans their sum
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.isnull())

# %%
null_var=df.isnull().sum()/df.shape[0]*100   #%of missing values
null_var
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %%
drop_columns=null_var[null_var>17].keys()
drop_columns
# Out:
# Index(['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
df2=df.drop(columns=drop_columns) #new dataframe df2 after column drop

# %%
df2.shape     #remaining 75 columns only
# Out:
# (1460, 75)

# %%
plt.figure(figsize=(25,25)) #new hetmap after dropping columns having null values >17%
sns.heatmap(df2.isnull())

# %%
df3=df2.dropna() #we removed all the rows having any null values, so left rows are 1338
df3.shape
# Out:
# (1338, 75)

# %%
plt.figure(figsize=(25,25)) #new heatmap after dropping rows having any null values
sns.heatmap(df3.isnull())

# %%
df3.isnull().sum() #now we can see here not a single misssing values
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# ...

# %%
df3.isnull().sum().sum()  #combined sum
# Out:
# 0

# %%
df3.select_dtypes(include=['int64','float64']).columns   #only numerical columns
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
sns.distplot(df['MSSubClass']) #df distplot for 2nd column of original dataframe

# %%
sns.distplot(df3['MSSubClass'])#df3 distplot for 2nd column of original dataframe

# %%
sns.distplot(df['MSSubClass'])    #overlapping both dataframes df,df3's particular column not too much difference
sns.distplot(df3['MSSubClass'])

# %%
num_var=['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
       'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
       'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
       'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
       'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
       'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
       'MoSold', 'YrSold', 'SalePrice']

plt.figure(figsize=(25,25))
for i, var in enumerate(num_var):
    plt.subplot(9,4, i+1)
    sns.distplot(df[var],bins=20)    
    sns.distplot(df3[var],bins=20)

# %% [markdown]
# ### Above we shaw the Data distribution of numeric features now we will see for cateogrical variable

# %%
df3.select_dtypes(include=['object']).columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
df['MSZoning'].value_counts()/df3.shape[0]*100
# Out:
# RL         86.023916
# RM         16.292975
# FV          4.857997
# RH          1.195815
# C (all)     0.747384
# Name: MSZoning, dtype: float64

# %%
#concating both the dataframe before and after clean for MSZoning

# %%
pd.concat([df['MSZoning'].value_counts()/df.shape[0]*100,
          df3['MSZoning'].value_counts()/df3.shape[0]*100],axis=1,
         keys=['MSZoning_org','MSZoning_clean'])
# Out:
#          MSZoning_org  MSZoning_clean
# RL          78.835616       79.671151
# RM          14.931507       14.275037
# FV           4.452055        4.633782
# RH           1.095890        0.822123
# C (all)      0.684932        0.597907

# %%
def cat_var_dist(var):

    return pd.concat([df[var].value_counts()/df.shape[0]*100,
          df3[var].value_counts()/df3.shape[0]*100],axis=1,
         keys=[var+'org',var+'clean'])

# %%
cat_var_dist('MSZoning')
# Out:
#          MSZoningorg  MSZoningclean
# RL         78.835616      79.671151
# RM         14.931507      14.275037
# FV          4.452055       4.633782
# RH          1.095890       0.822123
# C (all)     0.684932       0.597907

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# #missing value imputation using mean meadian

# %%
#import important libraries
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading dataset

# %%
#dataset_path='https://drive.google.com/open?id=15NwPXOltqyEcs7BDbbjqaehUrW14WNXS'
#use us?export=download& in place of open?
dataset_path='https://drive.google.com/uc?export=downloads&id=15NwPXOltqyEcs7BDbbjqaehUrW14WNXS' 
ds=pd.read_csv(dataset_path)

# %%
ds.shape
# Out:
# (1460, 81)

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_rows',None)

ds.head(6)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
ds.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
miss_value_percent=ds.isnull().sum()/ds.shape[0]*100   #%of missing values
miss_value_percent
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %%
drop_columns=miss_value_percent[miss_value_percent>17].keys()
drop_columns
# Out:
# Index(['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
ds2=ds.drop(columns=drop_columns) #new dataframe df2 after column drop

# %%
ds2.shape
# Out:
# (1460, 75)

# %%
ds2.select_dtypes(include=['int64','float64']).columns#only numerical columns
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
ds3=ds2.select_dtypes(include=['int64','float64'])
ds3.head(6)
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
# 5   6          50    14115            5            5       1993          1995
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0       196.0         706           0        150          856       856
# 1         0.0         978           0        284         1262      1262
# 2       162.0         486           0        434          920       920
# 3         0.0         216           0        540          756       961
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(ds3)

# %%
ds3[ds3.isnull().any(axis=1)]
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 39      40          90     6040            4            5       1955
# 48      49         190     4456            4            5       1920
# 78      79          90    10778            4            5       1968
# 88      89          50     8470            3            2       1915
# 89      90          20     8070            4            5       1994
# 99     100          20     9320            4            5       1959
# 108    109          50     8500            5            7       1919
# 125    126         190     6780            6            8       1935
# 127    128          45     4388            5            7       1930
# 140    141          20    10500            4            5       1971
# 148    149          20     7500            7            5       2004
# 155    156          50     9600            6            5       1924
# 163    164          45     5500            4            6       1956
# ...

# %%
ds3.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# LotArea           0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# MasVnrArea        8
# BsmtFinSF1        0
# BsmtFinSF2        0
# BsmtUnfSF         0
# TotalBsmtSF       0
# 1stFlrSF          0
# 2ndFlrSF          0
# LowQualFinSF      0
# GrLivArea         0
# BsmtFullBath      0
# BsmtHalfBath      0
# FullBath          0
# HalfBath          0
# BedroomAbvGr      0
# KitchenAbvGr      0
# TotRmsAbvGrd      0
# Fireplaces        0
# GarageYrBlt      81
# GarageCars        0
# GarageArea        0
# WoodDeckSF        0
# OpenPorchSF       0
# EnclosedPorch     0
# 3SsnPorch         0
# ScreenPorch       0
# PoolArea          0
# MiscVal           0
# MoSold            0
# YrSold            0
# SalePrice         0
# dtype: int64

# %%
miss_num_var=[var for var in ds3.columns if ds3[var].isnull().sum()>0]
miss_num_var
# Out:
# ['MasVnrArea', 'GarageYrBlt']

# %%
plt.figure(figsize=(16,9))

sns.set()
for i ,var in enumerate(miss_num_var):
    plt.subplot(1,2,i+1)
    sns.distplot(ds3[var],bins=20,kde_kws={'linewidth':5,'color':'k'})

# %%
ds4=ds3.fillna(ds3.mean())   #NaN value filled by mean value
ds4.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(16,9))

sns.set()
for i ,var in enumerate(miss_num_var):
    plt.subplot(1,2,i+1)
    sns.distplot(ds3[var],bins=20,kde_kws={'linewidth':8,'color':'k'},label='original')
    sns.distplot(ds4[var],bins=20,kde_kws={'linewidth':5,'color':'y'},label='mean')
    
    plt.legend()

# %%
ds5=ds3.fillna(ds3.mean())   #NaN value filled by median value
ds5.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(16,9))

sns.set()
for i ,var in enumerate(miss_num_var):
    plt.subplot(1,2,i+1)
    sns.distplot(ds3[var],bins=20,hist=False,kde_kws={'linewidth':8,'color':'k'},label='original')
    sns.distplot(ds4[var],bins=20,hist=False,kde_kws={'linewidth':5,'color':'c'},label='mean')
    sns.distplot(ds5[var],bins=20,hist=False,kde_kws={'linewidth':3,'color':'r'},label='median')
    plt.legend()

# %% [markdown]
# # BoxPlot for original data,mean data and median data

# %%
for i, var in enumerate(miss_num_var):
    plt.figure(figsize=(16,9))
    
    plt.subplot(3,1,1)
    sns.boxplot(ds[var])
    
    plt.subplot(3,1,1)
    sns.boxplot(ds4[var])
    
    plt.subplot(3,1,1)
    sns.boxplot(ds5[var])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   import sys
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # Remove the CWD from sys.path while we load stuff.
# ...

# %%
ds_concat= pd.concat([ds3[miss_num_var],ds4[miss_num_var],ds5[miss_num_var],])
ds_concat[ds_concat.isnull().any(axis=1)]
# Out:
#       MasVnrArea  GarageYrBlt
# 39           0.0          NaN
# 48           0.0          NaN
# 78           0.0          NaN
# 88           0.0          NaN
# 89           0.0          NaN
# 99           0.0          NaN
# 108          0.0          NaN
# 125          0.0          NaN
# 127          0.0          NaN
# 140          0.0          NaN
# 148        120.0          NaN
# 155          0.0          NaN
# 163          0.0          NaN
# 165          0.0          NaN
# 198          0.0          NaN
# 210          0.0          NaN
# 234          NaN       2002.0
# 241          0.0          NaN
# 250          0.0          NaN
# 287          0.0          NaN
# 291          0.0          NaN
# 307          0.0          NaN
# 375          0.0          NaN
# 386          0.0          NaN
# 393          0.0          NaN
# 431          0.0          NaN
# 434          0.0          NaN
# 441        270.0          NaN
# 464        136.0          NaN
# 495          0.0          NaN
# ...
